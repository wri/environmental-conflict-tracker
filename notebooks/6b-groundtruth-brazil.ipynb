# %% [markdown]
# # 1 Introduction
#
# ## 1.0 Package imports

# %%
import numpy as np
import pandas as pd
from googletrans import Translator
import time
import warnings
import tabula

# %% [markdown]
# # 2 Definitions
#
# ## 2.0 Parameter definitions

# %%
data_location = '../data/brazil/groundtruth-brazil.csv'
data_location_en = '../data/brazil/groundtruth-brazil-en.csv'
data_location_pdf = '../data/brazil/groundtruth-brazil.pdf'

# %% [markdown]
# ## 2.1 Function definitions

# %%
translator = Translator()

def translate_worker(string: str, translator: 'Translator' = translator) -> str:
    if string == 'nan' or pd.isna(string):
        return string
    
    language = translator.detect(string)
    if language.lang != 'en':
        time.sleep(3)
        string_trans = translator.translate(string)
        if string_trans.src in ['pt', 'es']:
        #assert (string.src in ['id', 'ms', 'jw', 'su', 'gu']), f'Incorrect input language of {string.src}'
            string = string_trans.text
        else:
            warnings.warn(f'Incorrect language of {string_trans.src}')
    return string

# %% [markdown]
# # 3 Execution

# %% [markdown]
# ## 3.0 Convert PDF to CSV

# %%
df = tabula.read_pdf(data_location_pdf, pages='all', encoding='utf-8')
df_colnames = ['State', 'City', 'Conflict Name', 'Area', 'Date',
               'Families Involved', 'Property Type', 'Jurisdiction', 
               'Families displaced', 'Attempt Threat Expulsion', 'Eviction',
               'Eviction threats', 'Houses Destroyed', 'Land destroyed', 'Belongings Destroyed', 
               'Guns', 'Invasion', 'Result', 'Cause', 'Type of Violence']

cols_to_keep = ['State', 'City', 'Conflict Name', 'Area', 'Date', 'Families Involved', 'Property Type',
                'Jurisdiction', 'Result', 'Cause', 'Type of Violence']

for x in range(len(df)):
    df[x].columns = df_colnames

df = pd.concat(df)
df = df.drop([x for x in df.columns if x not in cols_to_keep], axis = 1)
df = df[df['State'] != 'Estado']
df = df.dropna(thresh = df.shape[1] -3)
df = df.reset_index()
df = df.drop('index', axis = 1)

for column in df.columns:
    for row in range(0, len(df)):
        if isinstance(df[column][row], str):
            df[column][row] = df[column][row].replace('\r', ' ')
            df[column][row] = df[column][row].replace('/', ' ')

# %%
df.tail(5)
# Out:
#     State                                      City  \
# 903    TO                            Porto Nacional
# 904    TO                            Porto Nacional
# 905    TO                 Santa Tereza do Tocantins
# 906    TO                    São Félix do Tocantins
# 907    TO  Tocantinópolis  Maurilândia do Tocantins
#
#                                        Conflict Name Area        Date  \
# 903  P. A. Retiro Acamp. D. Celso Pereira de Almeida  NaN  21 09 2018
# 904               Faz. Chianini Acamp. Marielle Vive  NaN  31 07 2018
# 905           Comunidade Quilombola Barra do Aroeira  NaN  31 12 2018
# 906            Comunidade Quilombola do Rio do Prata  NaN  31 12 2018
# 907    T. I. Apinajé Apinayés UHE Serra Quebrada PAC  NaN  14 02 2018
#
#     Families Involved         Property Type                Jurisdiction  \
# 903                40  Área de assentamento               Assentamen to
# 904                20      Pública Grilad a                     Litígio
# 905               174       Área quilombola                 Certificada
# 906                78       Área quilombola  Em fase de Reconhecim ento
# 907               227         Área indígena                  Homologada
#
#           Result            Cause         Type of Violence
# 903    Sem Terra  Governo federal                      NaN
# 904    Sem Terra         Grileiro          Ameaça de Morte
# 905  Quilombolas       Fazendeiro   Ameaça de Expropriação
# 906  Quilombolas       Fazendeiro  Impedimento de ir e vir
# 907    Indígenas       Fazendeiro                    Danos

# %%
df.to_csv(data_location, index = False)

# %% [markdown]
# ## 3.1 Translate Portuguese to English

# %%
data = pd.read_csv(data_location_en)
cols_to_translate = ['Property Type', 'Jurisdiction', 
                     'Result', 'Cause', 'Type of Violence'] # 0-1 already done
data.tail(5)
# Out:
#     State                                      City  \
# 903    TO                            Porto Nacional
# 904    TO                            Porto Nacional
# 905    TO                 Santa Tereza do Tocantins
# 906    TO                    São Félix do Tocantins
# 907    TO  Tocantinópolis  Maurilândia do Tocantins
#
#                                        Conflict Name  Area        Date  \
# 903  P. A. Retiro Acamp. D. Celso Pereira de Almeida   NaN  21 09 2018
# 904               Faz. Chianini Acamp. Marielle Vive   NaN  31 07 2018
# 905           Comunidade Quilombola Barra do Aroeira   NaN  31 12 2018
# 906            Comunidade Quilombola do Rio do Prata   NaN  31 12 2018
# 907    T. I. Apinajé Apinayés UHE Serra Quebrada PAC   NaN  14 02 2018
#
#      Families Involved     Property Type                Jurisdiction  \
# 903               40.0      Nesting Area               Assentamen to
# 904               20.0  Public Grilad to                     Litígio
# 905              174.0     quilombo area                 Certificada
# 906               78.0     quilombo area  Em fase de Reconhecim ento
# 907              227.0   indigenous area                  Homologada
#
#           Result            Cause         Type of Violence
# 903    Sem Terra  Governo federal                      NaN
# 904    Sem Terra         Grileiro          Ameaça de Morte
# 905  Quilombolas       Fazendeiro   Ameaça de Expropriação
# 906  Quilombolas       Fazendeiro  Impedimento de ir e vir
# 907    Indígenas       Fazendeiro                    Danos

# %%
for i in range(len(data)):
    data['Jurisdiction'][i] = data['Jurisdiction'][i].replace(" ento", "ento")
    if data['Jurisdiction'][i].count(" ") == 1:
        data['Jurisdiction'][i] = data['Jurisdiction'][i].replace(" ", "")
    data['Jurisdiction'][i] = data['Jurisdiction'][i].replace("  ç", "ç")
    data['Jurisdiction'][i] = data['Jurisdiction'][i].replace("aT", "a T")
# Out:
# /Users/john.brandt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/john.brandt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/john.brandt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/john.brandt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
for col in cols_to_translate[1:2]:
    print(col)
    for row in range(0, len(data)):
        print(row)
        text = translate_worker(data[col][row])
        print(f'Translated {data[col][row]} to {text} for column {col}, row {row}')
        print('\n')
        data[col][row] = text
# Out:
# Jurisdiction
# 0
# Translated Litígio to litigation for column Jurisdiction, row 0
#
#
# 1
# /Users/john.brandt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Translated Litígio to litigation for column Jurisdiction, row 1
#
#
# 2
# Translated Litígio to litigation for column Jurisdiction, row 2
#
#
# 3
# Translated Litígio to litigation for column Jurisdiction, row 3
#
#
# 4
# Translated Litígio to litigation for column Jurisdiction, row 4
#
#
# 5
# Translated Litígio to litigation for column Jurisdiction, row 5
#
#
# 6
# Translated Litígio to litigation for column Jurisdiction, row 6
#
#
# 7
# Translated Litígio to litigation for column Jurisdiction, row 7
#
#
# 8
# Translated Litígio to litigation for column Jurisdiction, row 8
#
#
# 9
# Translated Litígio to litigation for column Jurisdiction, row 9
#
#
# 10
# Translated Litígio to litigation for column Jurisdiction, row 10
#
#
# 11
# Translated Litígio to litigation for column Jurisdiction, row 11
#
#
# 12
# Translated Litígio to litigation for column Jurisdiction, row 12
#
#
# 13
# Translated Litígio to litigation for column Jurisdiction, row 13
#
#
# 14
# Translated Litígio to litigation for column Jurisdiction, row 14
#
#
# 15
# Translated Litígio to litigation for column Jurisdiction, row 15
#
#
# 16
# Translated Litígio to litigation for column Jurisdiction, row 16
#
#
# 17
# Translated Litígio to litigation for column Jurisdiction, row 17
#
#
# 18
# Translated Litígio to litigation for column Jurisdiction, row 18
#
#
# 19
# Translated Litígio to litigation for column Jurisdiction, row 19
#
#
# 20
# Translated Litígio to litigation for column Jurisdiction, row 20
#
#
# 21
# Translated Litígio to litigation for column Jurisdiction, row 21
#
#
# 22
# Translated Litígio to litigation for column Jurisdiction, row 22
#
#
# 23
# Translated Litígio to litigation for column Jurisdiction, row 23
#
#
# 24
# Translated Litígio to litigation for column Jurisdiction, row 24
#
#
# 25
# Translated Litígio to litigation for column Jurisdiction, row 25
#
#
# 26
# Translated Litígio to litigation for column Jurisdiction, row 26
#
#
# 27
# Translated Litígio to litigation for column Jurisdiction, row 27
#
#
# 28
# Translated Litígio to litigation for column Jurisdiction, row 28
#
#
# 29
# Translated Litígio to litigation for column Jurisdiction, row 29
#
#
# 30
# Translated Litígio to litigation for column Jurisdiction, row 30
#
#
# 31
# Translated Litígio to litigation for column Jurisdiction, row 31
#
#
# 32
# Translated Litígio to litigation for column Jurisdiction, row 32
#
#
# 33
# Translated Litígio to litigation for column Jurisdiction, row 33
#
#
# 34
# Translated Litígio to litigation for column Jurisdiction, row 34
#
#
# 35
# Translated Litígio to litigation for column Jurisdiction, row 35
#
#
# 36
# Translated Desapropria ção Suspensa to expropriation Suspended for column Jurisdiction, row 36
#
#
# 37
# Translated Litígio to litigation for column Jurisdiction, row 37
#
#
# 38
# Translated Litígio to litigation for column Jurisdiction, row 38
#
#
# 39
# Translated Litígio to litigation for column Jurisdiction, row 39
#
#
# 40
# Translated Litígio to litigation for column Jurisdiction, row 40
#
#
# 41
# Translated Litígio to litigation for column Jurisdiction, row 41
#
#
# 42
# Translated Litígio to litigation for column Jurisdiction, row 42
#
#
# 43
# Translated Litígio to litigation for column Jurisdiction, row 43
#
#
# 44
# Translated Litígio to litigation for column Jurisdiction, row 44
#
#
# 45
# Translated Litígio to litigation for column Jurisdiction, row 45
#
#
# 46
# Translated Litígio to litigation for column Jurisdiction, row 46
#
#
# 47
# Translated Litígio to litigation for column Jurisdiction, row 47
#
#
# 48
# Translated Litígio to litigation for column Jurisdiction, row 48
#
#
# 49
# Translated Litígio to litigation for column Jurisdiction, row 49
#
#
# 50
# Translated Litígio to litigation for column Jurisdiction, row 50
#
#
# 51
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 51
#
#
# 52
# Translated Litígio to litigation for column Jurisdiction, row 52
#
#
# 53
# Translated Litígio to litigation for column Jurisdiction, row 53
#
#
# 54
# Translated Litígio to litigation for column Jurisdiction, row 54
#
#
# 55
# Translated Litígio to litigation for column Jurisdiction, row 55
#
#
# 56
# Translated Litígio to litigation for column Jurisdiction, row 56
#
#
# 57
# Translated Indefinida to indefinite for column Jurisdiction, row 57
#
#
# 58
# Translated Grilada to illegally taken for column Jurisdiction, row 58
#
#
# 59
# Translated Grilada to illegally taken for column Jurisdiction, row 59
#
#
# 60
# Translated Litígio to litigation for column Jurisdiction, row 60
#
#
# 61
# Translated Litígio to litigation for column Jurisdiction, row 61
#
#
# 62
# Translated Grilada to illegally taken for column Jurisdiction, row 62
#
#
# 63
# Translated Grilada to illegally taken for column Jurisdiction, row 63
#
#
# 64
# Translated Grilada to illegally taken for column Jurisdiction, row 64
#
#
# 65
# Translated Litígio to litigation for column Jurisdiction, row 65
#
#
# 66
# Translated Litígio to litigation for column Jurisdiction, row 66
#
#
# 67
# Translated Litígio to litigation for column Jurisdiction, row 67
#
#
# 68
# Translated Grilada to illegally taken for column Jurisdiction, row 68
#
#
# 69
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 69
#
#
# 70
# Translated Indefinida to indefinite for column Jurisdiction, row 70
#
#
# 71
# Translated Litígio to litigation for column Jurisdiction, row 71
#
#
# 72
# Translated Grilada to illegally taken for column Jurisdiction, row 72
#
#
# 73
# Translated Grilada to illegally taken for column Jurisdiction, row 73
#
#
# 74
# Translated Litígio to litigation for column Jurisdiction, row 74
#
#
# 75
# Translated Litígio to litigation for column Jurisdiction, row 75
#
#
# 76
# Translated Litígio to litigation for column Jurisdiction, row 76
#
#
# 77
# Translated Litígio to litigation for column Jurisdiction, row 77
#
#
# 78
# Translated Litígio to litigation for column Jurisdiction, row 78
#
#
# 79
# Translated Litígio to litigation for column Jurisdiction, row 79
#
#
# 80
# Translated Litígio to litigation for column Jurisdiction, row 80
#
#
# 81
# Translated Litígio to litigation for column Jurisdiction, row 81
#
#
# 82
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 82
#
#
# 83
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 83
#
#
# 84
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 84
#
#
# 85
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 85
#
#
# 86
# Translated Litígio to litigation for column Jurisdiction, row 86
#
#
# 87
# Translated Arrecadaçã o to Collection for column Jurisdiction, row 87
#
#
# 88
# Translated Litígio to litigation for column Jurisdiction, row 88
#
#
# 89
# Translated Litígio to litigation for column Jurisdiction, row 89
#
#
# 90
# Translated Litígio to litigation for column Jurisdiction, row 90
#
#
# 91
# Translated Litígio to litigation for column Jurisdiction, row 91
#
#
# 92
# Translated Arrecadaçã o to Collection for column Jurisdiction, row 92
#
#
# 93
# Translated Litígio to litigation for column Jurisdiction, row 93
#
#
# 94
# Translated Grilada to illegally taken for column Jurisdiction, row 94
#
#
# 95
# Translated Litígio to litigation for column Jurisdiction, row 95
#
#
# 96
# Translated Litígio to litigation for column Jurisdiction, row 96
#
#
# 97
# Translated Litígio to litigation for column Jurisdiction, row 97
#
#
# 98
# Translated Litígio to litigation for column Jurisdiction, row 98
#
#
# 99
# Translated Litígio to litigation for column Jurisdiction, row 99
#
#
# 100
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 100
#
#
# 101
# Translated Litígio to litigation for column Jurisdiction, row 101
#
#
# 102
# Translated Litígio to litigation for column Jurisdiction, row 102
#
#
# 103
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 103
#
#
# 104
# Translated Termo de Autorização de Uso to Terms of Service Authorization for column Jurisdiction, row 104
#
#
# 105
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 105
#
#
# 106
# Translated Homologada to homologated for column Jurisdiction, row 106
#
#
# 107
# Translated Litígio to litigation for column Jurisdiction, row 107
#
#
# 108
# Translated Litígio to litigation for column Jurisdiction, row 108
#
#
# 109
# Translated Litígio to litigation for column Jurisdiction, row 109
#
#
# 110
# Translated Litígio to litigation for column Jurisdiction, row 110
#
#
# 111
# Translated Homologada to homologated for column Jurisdiction, row 111
#
#
# 112
# Translated Litígio to litigation for column Jurisdiction, row 112
#
#
# 113
# Translated Litígio to litigation for column Jurisdiction, row 113
#
#
# 114
# Translated Litígio to litigation for column Jurisdiction, row 114
#
#
# 115
# Translated Homologada to homologated for column Jurisdiction, row 115
#
#
# 116
# Translated Homologada to homologated for column Jurisdiction, row 116
#
#
# 117
# Translated Demarcada to demarcated for column Jurisdiction, row 117
#
#
# 118
# Translated Homologada to homologated for column Jurisdiction, row 118
#
#
# 119
# Translated Homologada to homologated for column Jurisdiction, row 119
#
#
# 120
# Translated Litígio to litigation for column Jurisdiction, row 120
#
#
# 121
# Translated Litígio to litigation for column Jurisdiction, row 121
#
#
# 122
# Translated Homologada to homologated for column Jurisdiction, row 122
#
#
# 123
# Translated Sem informação to No information for column Jurisdiction, row 123
#
#
# 124
# Translated Litígio to litigation for column Jurisdiction, row 124
#
#
# 125
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 125
#
#
# 126
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 126
#
#
# 127
# Translated Desapropria da to expropriate the for column Jurisdiction, row 127
#
#
# 128
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 128
#
#
# 129
# Translated Litígio to litigation for column Jurisdiction, row 129
#
#
# 130
# Translated Litígio to litigation for column Jurisdiction, row 130
#
#
# 131
# Translated Litígio to litigation for column Jurisdiction, row 131
#
#
# 132
# Translated Litígio to litigation for column Jurisdiction, row 132
#
#
# 133
# Translated Litígio to litigation for column Jurisdiction, row 133
#
#
# 134
# Translated Litígio to litigation for column Jurisdiction, row 134
#
#
# 135
# Translated Litígio to litigation for column Jurisdiction, row 135
#
#
# 136
# Translated Litígio to litigation for column Jurisdiction, row 136
#
#
# 137
# Translated Homologada to homologated for column Jurisdiction, row 137
#
#
# 138
# Translated Litígio to litigation for column Jurisdiction, row 138
#
#
# 139
# Translated Homologada to homologated for column Jurisdiction, row 139
#
#
# 140
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 140
#
#
# 141
# Translated Litígio to litigation for column Jurisdiction, row 141
#
#
# 142
# Translated Homologada to homologated for column Jurisdiction, row 142
#
#
# 143
# Translated Certificada to certified for column Jurisdiction, row 143
#
#
# 144
# Translated Litígio to litigation for column Jurisdiction, row 144
#
#
# 145
# Translated Litígio to litigation for column Jurisdiction, row 145
#
#
# 146
# Translated Litígio to litigation for column Jurisdiction, row 146
#
#
# 147
# Translated Litígio to litigation for column Jurisdiction, row 147
#
#
# 148
# Translated Litígio to litigation for column Jurisdiction, row 148
#
#
# 149
# Translated Reconhecid a to Reconhecid the for column Jurisdiction, row 149
#
#
# 150
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 150
#
#
# 151
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 151
#
#
# 152
# Translated Em desapropria ção to in expropriation for column Jurisdiction, row 152
#
#
# 153
# Translated Litígio to litigation for column Jurisdiction, row 153
#
#
# 154
# Translated Litígio to litigation for column Jurisdiction, row 154
#
#
# 155
# Translated Litígio to litigation for column Jurisdiction, row 155
#
#
# 156
# Translated Litígio to litigation for column Jurisdiction, row 156
#
#
# 157
# Translated Litígio to litigation for column Jurisdiction, row 157
#
#
# 158
# Translated Litígio to litigation for column Jurisdiction, row 158
#
#
# 159
# Translated Desapropria da to expropriate the for column Jurisdiction, row 159
#
#
# 160
# Translated Litígio to litigation for column Jurisdiction, row 160
#
#
# 161
# Translated Litígio to litigation for column Jurisdiction, row 161
#
#
# 162
# Translated Litígio to litigation for column Jurisdiction, row 162
#
#
# 163
# Translated Litígio to litigation for column Jurisdiction, row 163
#
#
# 164
# Translated Litígio to litigation for column Jurisdiction, row 164
#
#
# 165
# Translated Litígio to litigation for column Jurisdiction, row 165
#
#
# 166
# Translated Litígio to litigation for column Jurisdiction, row 166
#
#
# 167
# Translated Litígio to litigation for column Jurisdiction, row 167
#
#
# 168
# Translated Litígio to litigation for column Jurisdiction, row 168
#
#
# 169
# Translated Litígio to litigation for column Jurisdiction, row 169
#
#
# 170
# Translated Litígio to litigation for column Jurisdiction, row 170
#
#
# 171
# Translated Litígio to litigation for column Jurisdiction, row 171
#
#
# 172
# Translated Litígio to litigation for column Jurisdiction, row 172
#
#
# 173
# Translated Litígio to litigation for column Jurisdiction, row 173
#
#
# 174
# Translated Litígio to litigation for column Jurisdiction, row 174
#
#
# 175
# Translated Litígio to litigation for column Jurisdiction, row 175
#
#
# 176
# Translated Litígio to litigation for column Jurisdiction, row 176
#
#
# 177
# Translated Litígio to litigation for column Jurisdiction, row 177
#
#
# 178
# Translated Litígio to litigation for column Jurisdiction, row 178
#
#
# 179
# Translated Litígio to litigation for column Jurisdiction, row 179
#
#
# 180
# Translated Litígio to litigation for column Jurisdiction, row 180
#
#
# 181
# Translated Litígio to litigation for column Jurisdiction, row 181
#
#
# 182
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 182
#
#
# 183
# Translated Litígio to litigation for column Jurisdiction, row 183
#
#
# 184
# Translated Reconhecid a to Reconhecid the for column Jurisdiction, row 184
#
#
# 185
# Translated Litígio to litigation for column Jurisdiction, row 185
#
#
# 186
# Translated Litígio to litigation for column Jurisdiction, row 186
#
#
# 187
# Translated Litígio to litigation for column Jurisdiction, row 187
#
#
# 188
# Translated Litígio to litigation for column Jurisdiction, row 188
#
#
# 189
# Translated Litígio to litigation for column Jurisdiction, row 189
#
#
# 190
# Translated Litígio to litigation for column Jurisdiction, row 190
#
#
# 191
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 191
#
#
# 192
# Translated Certificada to certified for column Jurisdiction, row 192
#
#
# 193
# Translated Certificada to certified for column Jurisdiction, row 193
#
#
# 194
# Translated Certificada to certified for column Jurisdiction, row 194
#
#
# 195
# Translated Certificada to certified for column Jurisdiction, row 195
#
#
# 196
# Translated Certificada to certified for column Jurisdiction, row 196
#
#
# 197
# Translated Sem informação to No information for column Jurisdiction, row 197
#
#
# 198
# Translated Sem informação to No information for column Jurisdiction, row 198
#
#
# 199
# Translated Litígio to litigation for column Jurisdiction, row 199
#
#
# 200
# Translated Certificada to certified for column Jurisdiction, row 200
#
#
# 201
# Translated Certificada to certified for column Jurisdiction, row 201
#
#
# 202
# Translated Certificada to certified for column Jurisdiction, row 202
#
#
# 203
# Translated Certificada to certified for column Jurisdiction, row 203
#
#
# 204
# Translated Certificada to certified for column Jurisdiction, row 204
#
#
# 205
# Translated Certificada to certified for column Jurisdiction, row 205
#
#
# 206
# Translated Certificada to certified for column Jurisdiction, row 206
#
#
# 207
# Translated Certificada to certified for column Jurisdiction, row 207
#
#
# 208
# Translated Certificada to certified for column Jurisdiction, row 208
#
#
# 209
# Translated Certificada to certified for column Jurisdiction, row 209
#
#
# 210
# Translated Certificada to certified for column Jurisdiction, row 210
#
#
# 211
# Translated Litígio to litigation for column Jurisdiction, row 211
#
#
# 212
# Translated Litígio to litigation for column Jurisdiction, row 212
#
#
# 213
# Translated Litígio to litigation for column Jurisdiction, row 213
#
#
# 214
# Translated Litígio to litigation for column Jurisdiction, row 214
#
#
# 215
# Translated Litígio to litigation for column Jurisdiction, row 215
#
#
# 216
# Translated Litígio to litigation for column Jurisdiction, row 216
#
#
# 217
# Translated Litígio to litigation for column Jurisdiction, row 217
#
#
# 218
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 218
#
#
# 219
# Translated Litígio to litigation for column Jurisdiction, row 219
#
#
# 220
# Translated Litígio to litigation for column Jurisdiction, row 220
#
#
# 221
# Translated Litígio to litigation for column Jurisdiction, row 221
#
#
# 222
# Translated Litígio to litigation for column Jurisdiction, row 222
#
#
# 223
# Translated Litígio to litigation for column Jurisdiction, row 223
#
#
# 224
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 224
#
#
# 225
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 225
#
#
# 226
# Translated Litígio to litigation for column Jurisdiction, row 226
#
#
# 227
# Translated Litígio to litigation for column Jurisdiction, row 227
#
#
# 228
# Translated Litígio to litigation for column Jurisdiction, row 228
#
#
# 229
# Translated Litígio to litigation for column Jurisdiction, row 229
#
#
# 230
# Translated Litígio to litigation for column Jurisdiction, row 230
#
#
# 231
# Translated Delimitada to bounded for column Jurisdiction, row 231
#
#
# 232
# Translated Litígio to litigation for column Jurisdiction, row 232
#
#
# 233
# Translated Litígio to litigation for column Jurisdiction, row 233
#
#
# 234
# Translated Litígio to litigation for column Jurisdiction, row 234
#
#
# 235
# Translated Litígio to litigation for column Jurisdiction, row 235
#
#
# 236
# Translated Litígio to litigation for column Jurisdiction, row 236
#
#
# 237
# Translated Litígio to litigation for column Jurisdiction, row 237
#
#
# 238
# Translated Litígio to litigation for column Jurisdiction, row 238
#
#
# 239
# Translated Reconhecid a to Reconhecid the for column Jurisdiction, row 239
#
#
# 240
# Translated Reconhecid a to Reconhecid the for column Jurisdiction, row 240
#
#
# 241
# Translated Reconhecid a to Reconhecid the for column Jurisdiction, row 241
#
#
# 242
# Translated Litígio to litigation for column Jurisdiction, row 242
#
#
# 243
# Translated Litígio to litigation for column Jurisdiction, row 243
#
#
# 244
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 244
#
#
# 245
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 245
#
#
# 246
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 246
#
#
# 247
# Translated Certificada to certified for column Jurisdiction, row 247
#
#
# 248
# Translated Certificada to certified for column Jurisdiction, row 248
#
#
# 249
# Translated Certificada to certified for column Jurisdiction, row 249
#
#
# 250
# Translated Certificada to certified for column Jurisdiction, row 250
#
#
# 251
# Translated Certificada to certified for column Jurisdiction, row 251
#
#
# 252
# Translated Certificada to certified for column Jurisdiction, row 252
#
#
# 253
# Translated Certificada to certified for column Jurisdiction, row 253
#
#
# 254
# Translated Certificada to certified for column Jurisdiction, row 254
#
#
# 255
# Translated Certificada to certified for column Jurisdiction, row 255
#
#
# 256
# Translated Certificada to certified for column Jurisdiction, row 256
#
#
# 257
# Translated Certificada to certified for column Jurisdiction, row 257
#
#
# 258
# Translated Certificada to certified for column Jurisdiction, row 258
#
#
# 259
# Translated Certificada to certified for column Jurisdiction, row 259
#
#
# 260
# Translated Certificada to certified for column Jurisdiction, row 260
#
#
# 261
# Translated Certificada to certified for column Jurisdiction, row 261
#
#
# 262
# Translated Certificada to certified for column Jurisdiction, row 262
#
#
# 263
# Translated Certificada to certified for column Jurisdiction, row 263
#
#
# 264
# Translated Certificada to certified for column Jurisdiction, row 264
#
#
# 265
# Translated Certificada to certified for column Jurisdiction, row 265
#
#
# 266
# Translated Litígio to litigation for column Jurisdiction, row 266
#
#
# 267
# Translated Litígio to litigation for column Jurisdiction, row 267
#
#
# 268
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 268
#
#
# 269
# Translated Litígio to litigation for column Jurisdiction, row 269
#
#
# 270
# Translated Sem informação to No information for column Jurisdiction, row 270
#
#
# 271
# Translated Litígio to litigation for column Jurisdiction, row 271
#
#
# 272
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 272
#
#
# 273
# Translated Litígio to litigation for column Jurisdiction, row 273
#
#
# 274
# Translated Litígio to litigation for column Jurisdiction, row 274
#
#
# 275
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 275
#
#
# 276
# Translated Litígio to litigation for column Jurisdiction, row 276
#
#
# 277
# Translated Litígio to litigation for column Jurisdiction, row 277
#
#
# 278
# Translated Litígio to litigation for column Jurisdiction, row 278
#
#
# 279
# Translated Litígio to litigation for column Jurisdiction, row 279
#
#
# 280
# Translated Litígio to litigation for column Jurisdiction, row 280
#
#
# 281
# Translated Litígio to litigation for column Jurisdiction, row 281
#
#
# 282
# Translated Litígio to litigation for column Jurisdiction, row 282
#
#
# 283
# Translated Litígio to litigation for column Jurisdiction, row 283
#
#
# 284
# Translated Litígio to litigation for column Jurisdiction, row 284
#
#
# 285
# Translated Litígio to litigation for column Jurisdiction, row 285
#
#
# 286
# Translated Litígio to litigation for column Jurisdiction, row 286
#
#
# 287
# Translated Litígio to litigation for column Jurisdiction, row 287
#
#
# 288
# Translated Litígio to litigation for column Jurisdiction, row 288
#
#
# 289
# Translated Sem informação to No information for column Jurisdiction, row 289
#
#
# 290
# Translated Desapropria da to expropriate the for column Jurisdiction, row 290
#
#
# 291
# Translated Litígio to litigation for column Jurisdiction, row 291
#
#
# 292
# Translated Litígio to litigation for column Jurisdiction, row 292
#
#
# 293
# Translated Litígio to litigation for column Jurisdiction, row 293
#
#
# 294
# Translated Litígio to litigation for column Jurisdiction, row 294
#
#
# 295
# Translated Homologada to homologated for column Jurisdiction, row 295
#
#
# 296
# Translated Homologada to homologated for column Jurisdiction, row 296
#
#
# 297
# Translated Desapropria da to expropriate the for column Jurisdiction, row 297
#
#
# 298
# Translated Litígio to litigation for column Jurisdiction, row 298
#
#
# 299
# Translated Litígio to litigation for column Jurisdiction, row 299
#
#
# 300
# Translated Litígio to litigation for column Jurisdiction, row 300
#
#
# 301
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 301
#
#
# 302
# Translated Litígio to litigation for column Jurisdiction, row 302
#
#
# 303
# Translated Litígio to litigation for column Jurisdiction, row 303
#
#
# 304
# Translated Litígio to litigation for column Jurisdiction, row 304
#
#
# 305
# Translated Homologada to homologated for column Jurisdiction, row 305
#
#
# 306
# Translated Litígio to litigation for column Jurisdiction, row 306
#
#
# 307
# Translated Vistoriada to inspected for column Jurisdiction, row 307
#
#
# 308
# Translated Litígio to litigation for column Jurisdiction, row 308
#
#
# 309
# Translated Litígio to litigation for column Jurisdiction, row 309
#
#
# 310
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 310
#
#
# 311
# Translated Litígio to litigation for column Jurisdiction, row 311
#
#
# 312
# Translated Litígio to litigation for column Jurisdiction, row 312
#
#
# 313
# Translated Litígio to litigation for column Jurisdiction, row 313
#
#
# 314
# Translated Litígio to litigation for column Jurisdiction, row 314
#
#
# 315
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 315
#
#
# 316
# Translated Litígio to litigation for column Jurisdiction, row 316
#
#
# 317
# Translated Reconhecid a to Reconhecid the for column Jurisdiction, row 317
#
#
# 318
# Translated Reconhecid a to Reconhecid the for column Jurisdiction, row 318
#
#
# 319
# Translated Reconhecid a to Reconhecid the for column Jurisdiction, row 319
#
#
# 320
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 320
#
#
# 321
# Translated Litígio to litigation for column Jurisdiction, row 321
#
#
# 322
# Translated Litígio to litigation for column Jurisdiction, row 322
#
#
# 323
# Translated Litígio to litigation for column Jurisdiction, row 323
#
#
# 324
# Translated Litígio to litigation for column Jurisdiction, row 324
#
#
# 325
# Translated Litígio to litigation for column Jurisdiction, row 325
#
#
# 326
# Translated Litígio to litigation for column Jurisdiction, row 326
#
#
# 327
# Translated Litígio to litigation for column Jurisdiction, row 327
#
#
# 328
# Translated Litígio to litigation for column Jurisdiction, row 328
#
#
# 329
# Translated Litígio to litigation for column Jurisdiction, row 329
#
#
# 330
# Translated Litígio to litigation for column Jurisdiction, row 330
#
#
# 331
# Translated Litígio to litigation for column Jurisdiction, row 331
#
#
# 332
# Translated Litígio to litigation for column Jurisdiction, row 332
#
#
# 333
# Translated Desapropria da to expropriate the for column Jurisdiction, row 333
#
#
# 334
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 334
#
#
# 335
# Translated Termo de Autorização de Uso to Terms of Service Authorization for column Jurisdiction, row 335
#
#
# 336
# Translated Certificada to certified for column Jurisdiction, row 336
#
#
# 337
# Translated Reconhecid a to Reconhecid the for column Jurisdiction, row 337
#
#
# 338
# Translated Litígio to litigation for column Jurisdiction, row 338
#
#
# 339
# Translated Litígio to litigation for column Jurisdiction, row 339
#
#
# 340
# Translated Litígio to litigation for column Jurisdiction, row 340
#
#
# 341
# Translated Litígio to litigation for column Jurisdiction, row 341
#
#
# 342
# Translated Litígio to litigation for column Jurisdiction, row 342
#
#
# 343
# Translated Litígio to litigation for column Jurisdiction, row 343
#
#
# 344
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 344
#
#
# 345
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 345
#
#
# 346
# Translated Litígio to litigation for column Jurisdiction, row 346
#
#
# 347
# Translated Litígio to litigation for column Jurisdiction, row 347
#
#
# 348
# Translated Litígio to litigation for column Jurisdiction, row 348
#
#
# 349
# Translated Litígio to litigation for column Jurisdiction, row 349
#
#
# 350
# Translated Litígio to litigation for column Jurisdiction, row 350
#
#
# 351
# Translated Litígio to litigation for column Jurisdiction, row 351
#
#
# 352
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 352
#
#
# 353
# Translated Litígio to litigation for column Jurisdiction, row 353
#
#
# 354
# Translated Litígio to litigation for column Jurisdiction, row 354
#
#
# 355
# Translated Litígio to litigation for column Jurisdiction, row 355
#
#
# 356
# Translated Litígio to litigation for column Jurisdiction, row 356
#
#
# 357
# Translated Litígio to litigation for column Jurisdiction, row 357
#
#
# 358
# Translated Litígio to litigation for column Jurisdiction, row 358
#
#
# 359
# Translated Litígio to litigation for column Jurisdiction, row 359
#
#
# 360
# Translated Reconhecid a to Reconhecid the for column Jurisdiction, row 360
#
#
# 361
# Translated Litígio to litigation for column Jurisdiction, row 361
#
#
# 362
# Translated Litígio to litigation for column Jurisdiction, row 362
#
#
# 363
# Translated Litígio to litigation for column Jurisdiction, row 363
#
#
# 364
# Translated Litígio to litigation for column Jurisdiction, row 364
#
#
# 365
# Translated Certificada to certified for column Jurisdiction, row 365
#
#
# 366
# Translated Homologada to homologated for column Jurisdiction, row 366
#
#
# 367
# Translated Desapropria da to expropriate the for column Jurisdiction, row 367
#
#
# 368
# Translated Litígio to litigation for column Jurisdiction, row 368
#
#
# 369
# Translated Litígio to litigation for column Jurisdiction, row 369
#
#
# 370
# Translated Litígio to litigation for column Jurisdiction, row 370
#
#
# 371
# Translated Litígio to litigation for column Jurisdiction, row 371
#
#
# 372
# Translated Litígio to litigation for column Jurisdiction, row 372
#
#
# 373
# Translated Reconhecid a to Reconhecid the for column Jurisdiction, row 373
#
#
# 374
# Translated Litígio to litigation for column Jurisdiction, row 374
#
#
# 375
# Translated Litígio to litigation for column Jurisdiction, row 375
#
#
# 376
# Translated Litígio to litigation for column Jurisdiction, row 376
#
#
# 377
# Translated Litígio to litigation for column Jurisdiction, row 377
#
#
# 378
# Translated Litígio to litigation for column Jurisdiction, row 378
#
#
# 379
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 379
#
#
# 380
# Translated Litígio to litigation for column Jurisdiction, row 380
#
#
# 381
# Translated Litígio to litigation for column Jurisdiction, row 381
#
#
# 382
# Translated Litígio to litigation for column Jurisdiction, row 382
#
#
# 383
# Translated Litígio to litigation for column Jurisdiction, row 383
#
#
# 384
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 384
#
#
# 385
# Translated Certificada to certified for column Jurisdiction, row 385
#
#
# 386
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 386
#
#
# 387
# Translated Litígio to litigation for column Jurisdiction, row 387
#
#
# 388
# Translated Litígio to litigation for column Jurisdiction, row 388
#
#
# 389
# Translated Litígio to litigation for column Jurisdiction, row 389
#
#
# 390
# Translated Litígio to litigation for column Jurisdiction, row 390
#
#
# 391
# Translated Litígio to litigation for column Jurisdiction, row 391
#
#
# 392
# Translated Em desapropria ção to in expropriation for column Jurisdiction, row 392
#
#
# 393
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 393
#
#
# 394
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 394
#
#
# 395
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 395
#
#
# 396
# Translated Desapropria da to expropriate the for column Jurisdiction, row 396
#
#
# 397
# Translated Litígio to litigation for column Jurisdiction, row 397
#
#
# 398
# Translated Litígio to litigation for column Jurisdiction, row 398
#
#
# 399
# Translated Litígio to litigation for column Jurisdiction, row 399
#
#
# 400
# Translated Litígio to litigation for column Jurisdiction, row 400
#
#
# 401
# Translated Litígio to litigation for column Jurisdiction, row 401
#
#
# 402
# Translated Litígio to litigation for column Jurisdiction, row 402
#
#
# 403
# Translated Litígio to litigation for column Jurisdiction, row 403
#
#
# 404
# Translated Litígio to litigation for column Jurisdiction, row 404
#
#
# 405
# Translated Litígio to litigation for column Jurisdiction, row 405
#
#
# 406
# Translated Litígio to litigation for column Jurisdiction, row 406
#
#
# 407
# Translated Litígio to litigation for column Jurisdiction, row 407
#
#
# 408
# Translated Sem informação to No information for column Jurisdiction, row 408
#
#
# 409
# Translated Litígio to litigation for column Jurisdiction, row 409
#
#
# 410
# Translated Litígio to litigation for column Jurisdiction, row 410
#
#
# 411
# Translated Litígio to litigation for column Jurisdiction, row 411
#
#
# 412
# Translated Litígio to litigation for column Jurisdiction, row 412
#
#
# 413
# Translated Litígio to litigation for column Jurisdiction, row 413
#
#
# 414
# Translated Certificada to certified for column Jurisdiction, row 414
#
#
# 415
# Translated Litígio to litigation for column Jurisdiction, row 415
#
#
# 416
# Translated Em desapropria ção to in expropriation for column Jurisdiction, row 416
#
#
# 417
# Translated Em desapropria ção to in expropriation for column Jurisdiction, row 417
#
#
# 418
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 418
#
#
# 419
# Translated Litígio to litigation for column Jurisdiction, row 419
#
#
# 420
# Translated Litígio to litigation for column Jurisdiction, row 420
#
#
# 421
# Translated Litígio to litigation for column Jurisdiction, row 421
#
#
# 422
# Translated Litígio to litigation for column Jurisdiction, row 422
#
#
# 423
# Translated Litígio to litigation for column Jurisdiction, row 423
#
#
# 424
# Translated Litígio to litigation for column Jurisdiction, row 424
#
#
# 425
# Translated Litígio to litigation for column Jurisdiction, row 425
#
#
# 426
# Translated Litígio to litigation for column Jurisdiction, row 426
#
#
# 427
# Translated Litígio to litigation for column Jurisdiction, row 427
#
#
# 428
# Translated Litígio to litigation for column Jurisdiction, row 428
#
#
# 429
# Translated Litígio to litigation for column Jurisdiction, row 429
#
#
# 430
# Translated Homologada to homologated for column Jurisdiction, row 430
#
#
# 431
# Translated Demarcada to demarcated for column Jurisdiction, row 431
#
#
# 432
# Translated Litígio to litigation for column Jurisdiction, row 432
#
#
# 433
# Translated Homologada to homologated for column Jurisdiction, row 433
#
#
# 434
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 434
#
#
# 435
# Translated Litígio to litigation for column Jurisdiction, row 435
#
#
# 436
# Translated Litígio to litigation for column Jurisdiction, row 436
#
#
# 437
# Translated Litígio to litigation for column Jurisdiction, row 437
#
#
# 438
# Translated Litígio to litigation for column Jurisdiction, row 438
#
#
# 439
# Translated Litígio to litigation for column Jurisdiction, row 439
#
#
# 440
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 440
#
#
# 441
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 441
#
#
# 442
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 442
#
#
# 443
# Translated Homologada to homologated for column Jurisdiction, row 443
#
#
# 444
# Translated Homologada to homologated for column Jurisdiction, row 444
#
#
# 445
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 445
#
#
# 446
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 446
#
#
# 447
# Translated Litígio to litigation for column Jurisdiction, row 447
#
#
# 448
# Translated Litígio to litigation for column Jurisdiction, row 448
#
#
# 449
# Translated Litígio to litigation for column Jurisdiction, row 449
#
#
# 450
# Translated Litígio to litigation for column Jurisdiction, row 450
#
#
# 451
# Translated Homologada to homologated for column Jurisdiction, row 451
#
#
# 452
# Translated Litígio to litigation for column Jurisdiction, row 452
#
#
# 453
# Translated Litígio to litigation for column Jurisdiction, row 453
#
#
# 454
# Translated Litígio to litigation for column Jurisdiction, row 454
#
#
# 455
# Translated Litígio to litigation for column Jurisdiction, row 455
#
#
# 456
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 456
#
#
# 457
# Translated Litígio to litigation for column Jurisdiction, row 457
#
#
# 458
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 458
#
#
# 459
# Translated Homologada to homologated for column Jurisdiction, row 459
#
#
# 460
# Translated Homologada to homologated for column Jurisdiction, row 460
#
#
# 461
# Translated Homologada to homologated for column Jurisdiction, row 461
#
#
# 462
# Translated Sem informação to No information for column Jurisdiction, row 462
#
#
# 463
# Translated Homologada to homologated for column Jurisdiction, row 463
#
#
# 464
# Translated Homologada to homologated for column Jurisdiction, row 464
#
#
# 465
# Translated Litígio to litigation for column Jurisdiction, row 465
#
#
# 466
# Translated Litígio to litigation for column Jurisdiction, row 466
#
#
# 467
# Translated Litígio to litigation for column Jurisdiction, row 467
#
#
# 468
# Translated Litígio to litigation for column Jurisdiction, row 468
#
#
# 469
# Translated Litígio to litigation for column Jurisdiction, row 469
#
#
# 470
# Translated Litígio to litigation for column Jurisdiction, row 470
#
#
# 471
# Translated Litígio to litigation for column Jurisdiction, row 471
#
#
# 472
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 472
#
#
# 473
# Translated Litígio to litigation for column Jurisdiction, row 473
#
#
# 474
# Translated Litígio to litigation for column Jurisdiction, row 474
#
#
# 475
# Translated Litígio to litigation for column Jurisdiction, row 475
#
#
# 476
# Translated Litígio to litigation for column Jurisdiction, row 476
#
#
# 477
# Translated Litígio to litigation for column Jurisdiction, row 477
#
#
# 478
# Translated Demarcada to demarcated for column Jurisdiction, row 478
#
#
# 479
# Translated Litígio to litigation for column Jurisdiction, row 479
#
#
# 480
# Translated Litígio to litigation for column Jurisdiction, row 480
#
#
# 481
# Translated Litígio to litigation for column Jurisdiction, row 481
#
#
# 482
# Translated Litígio to litigation for column Jurisdiction, row 482
#
#
# 483
# Translated Litígio to litigation for column Jurisdiction, row 483
#
#
# 484
# Translated Litígio to litigation for column Jurisdiction, row 484
#
#
# 485
# Translated Litígio to litigation for column Jurisdiction, row 485
#
#
# 486
# Translated Litígio to litigation for column Jurisdiction, row 486
#
#
# 487
# Translated Litígio to litigation for column Jurisdiction, row 487
#
#
# 488
# Translated Litígio to litigation for column Jurisdiction, row 488
#
#
# 489
# Translated Litígio to litigation for column Jurisdiction, row 489
#
#
# 490
# Translated Litígio to litigation for column Jurisdiction, row 490
#
#
# 491
# Translated Litígio to litigation for column Jurisdiction, row 491
#
#
# 492
# Translated Litígio to litigation for column Jurisdiction, row 492
#
#
# 493
# Translated Litígio to litigation for column Jurisdiction, row 493
#
#
# 494
# Translated Litígio to litigation for column Jurisdiction, row 494
#
#
# 495
# Translated Litígio to litigation for column Jurisdiction, row 495
#
#
# 496
# Translated Litígio to litigation for column Jurisdiction, row 496
#
#
# 497
# Translated Litígio to litigation for column Jurisdiction, row 497
#
#
# 498
# Translated Litígio to litigation for column Jurisdiction, row 498
#
#
# 499
# Translated Em desapropria ção to in expropriation for column Jurisdiction, row 499
#
#
# 500
# Translated Litígio to litigation for column Jurisdiction, row 500
#
#
# 501
# Translated Litígio to litigation for column Jurisdiction, row 501
#
#
# 502
# Translated Litígio to litigation for column Jurisdiction, row 502
#
#
# 503
# Translated Sem informação to No information for column Jurisdiction, row 503
#
#
# 504
# Translated Litígio to litigation for column Jurisdiction, row 504
#
#
# 505
# Translated Litígio to litigation for column Jurisdiction, row 505
#
#
# 506
# Translated Litígio to litigation for column Jurisdiction, row 506
#
#
# 507
# Translated Litígio to litigation for column Jurisdiction, row 507
#
#
# 508
# Translated Litígio to litigation for column Jurisdiction, row 508
#
#
# 509
# Translated Litígio to litigation for column Jurisdiction, row 509
#
#
# 510
# Translated Litígio to litigation for column Jurisdiction, row 510
#
#
# 511
# Translated Litígio to litigation for column Jurisdiction, row 511
#
#
# 512
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 512
#
#
# 513
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 513
#
#
# 514
# Translated Litígio to litigation for column Jurisdiction, row 514
#
#
# 515
# Translated Litígio to litigation for column Jurisdiction, row 515
#
#
# 516
# Translated Litígio to litigation for column Jurisdiction, row 516
#
#
# 517
# Translated Litígio to litigation for column Jurisdiction, row 517
#
#
# 518
# Translated Litígio to litigation for column Jurisdiction, row 518
#
#
# 519
# Translated Litígio to litigation for column Jurisdiction, row 519
#
#
# 520
# Translated Litígio to litigation for column Jurisdiction, row 520
#
#
# 521
# Translated Litígio to litigation for column Jurisdiction, row 521
#
#
# 522
# Translated Termo de Autorização de Uso to Terms of Service Authorization for column Jurisdiction, row 522
#
#
# 523
# Translated Termo de Autorização de Uso to Terms of Service Authorization for column Jurisdiction, row 523
#
#
# 524
# Translated Termo de Autorização de Uso to Terms of Service Authorization for column Jurisdiction, row 524
#
#
# 525
# Translated Litígio to litigation for column Jurisdiction, row 525
#
#
# 526
# Translated Litígio to litigation for column Jurisdiction, row 526
#
#
# 527
# Translated Litígio to litigation for column Jurisdiction, row 527
#
#
# 528
# Translated Litígio to litigation for column Jurisdiction, row 528
#
#
# 529
# Translated Litígio to litigation for column Jurisdiction, row 529
#
#
# 530
# Translated Litígio to litigation for column Jurisdiction, row 530
#
#
# 531
# Translated Reconhecid a to Reconhecid the for column Jurisdiction, row 531
#
#
# 532
# Translated Litígio to litigation for column Jurisdiction, row 532
#
#
# 533
# Translated Litígio to litigation for column Jurisdiction, row 533
#
#
# 534
# Translated Litígio to litigation for column Jurisdiction, row 534
#
#
# 535
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 535
#
#
# 536
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 536
#
#
# 537
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 537
#
#
# 538
# Translated Litígio to litigation for column Jurisdiction, row 538
#
#
# 539
# Translated Litígio to litigation for column Jurisdiction, row 539
#
#
# 540
# Translated Sem informação to No information for column Jurisdiction, row 540
#
#
# 541
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 541
#
#
# 542
# Translated Área Titulada to Entitled area for column Jurisdiction, row 542
#
#
# 543
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 543
#
#
# 544
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 544
#
#
# 545
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 545
#
#
# 546
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 546
#
#
# 547
# Translated Litígio to litigation for column Jurisdiction, row 547
#
#
# 548
# Translated Litígio to litigation for column Jurisdiction, row 548
#
#
# 549
# Translated Litígio to litigation for column Jurisdiction, row 549
#
#
# 550
# Translated Homologada to homologated for column Jurisdiction, row 550
#
#
# 551
# Translated Área Titulada to Entitled area for column Jurisdiction, row 551
#
#
# 552
# Translated Litígio to litigation for column Jurisdiction, row 552
#
#
# 553
# Translated Litígio to litigation for column Jurisdiction, row 553
#
#
# 554
# Translated Litígio to litigation for column Jurisdiction, row 554
#
#
# 555
# Translated Litígio to litigation for column Jurisdiction, row 555
#
#
# 556
# Translated Litígio to litigation for column Jurisdiction, row 556
#
#
# 557
# Translated Litígio to litigation for column Jurisdiction, row 557
#
#
# 558
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 558
#
#
# 559
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 559
#
#
# 560
# Translated Área Titulada to Entitled area for column Jurisdiction, row 560
#
#
# 561
# Translated Litígio to litigation for column Jurisdiction, row 561
#
#
# 562
# Translated Litígio to litigation for column Jurisdiction, row 562
#
#
# 563
# Translated Litígio to litigation for column Jurisdiction, row 563
#
#
# 564
# Translated Litígio to litigation for column Jurisdiction, row 564
#
#
# 565
# Translated Litígio to litigation for column Jurisdiction, row 565
#
#
# 566
# Translated Litígio to litigation for column Jurisdiction, row 566
#
#
# 567
# Translated Litígio to litigation for column Jurisdiction, row 567
#
#
# 568
# Translated Litígio to litigation for column Jurisdiction, row 568
#
#
# 569
# Translated Litígio to litigation for column Jurisdiction, row 569
#
#
# 570
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 570
#
#
# 571
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 571
#
#
# 572
# Translated Homologada to homologated for column Jurisdiction, row 572
#
#
# 573
# Translated Homologada to homologated for column Jurisdiction, row 573
#
#
# 574
# Translated Delimitada to bounded for column Jurisdiction, row 574
#
#
# 575
# Translated Litígio to litigation for column Jurisdiction, row 575
#
#
# 576
# Translated Homologada to homologated for column Jurisdiction, row 576
#
#
# 577
# Translated Homologada to homologated for column Jurisdiction, row 577
#
#
# 578
# Translated Litígio to litigation for column Jurisdiction, row 578
#
#
# 579
# Translated Litígio to litigation for column Jurisdiction, row 579
#
#
# 580
# Translated Litígio to litigation for column Jurisdiction, row 580
#
#
# 581
# Translated Litígio to litigation for column Jurisdiction, row 581
#
#
# 582
# Translated Litígio to litigation for column Jurisdiction, row 582
#
#
# 583
# Translated Litígio to litigation for column Jurisdiction, row 583
#
#
# 584
# Translated Litígio to litigation for column Jurisdiction, row 584
#
#
# 585
# Translated Litígio to litigation for column Jurisdiction, row 585
#
#
# 586
# Translated Litígio to litigation for column Jurisdiction, row 586
#
#
# 587
# Translated Litígio to litigation for column Jurisdiction, row 587
#
#
# 588
# Translated Reconhecid a to Reconhecid the for column Jurisdiction, row 588
#
#
# 589
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 589
#
#
# 590
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 590
#
#
# 591
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 591
#
#
# 592
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 592
#
#
# 593
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 593
#
#
# 594
# Translated Litígio to litigation for column Jurisdiction, row 594
#
#
# 595
# Translated Titulada to entitled for column Jurisdiction, row 595
#
#
# 596
# Translated Litígio to litigation for column Jurisdiction, row 596
#
#
# 597
# Translated Litígio to litigation for column Jurisdiction, row 597
#
#
# 598
# Translated Litígio to litigation for column Jurisdiction, row 598
#
#
# 599
# Translated Litígio to litigation for column Jurisdiction, row 599
#
#
# 600
# Translated Área Titulada to Entitled area for column Jurisdiction, row 600
#
#
# 601
# Translated Litígio to litigation for column Jurisdiction, row 601
#
#
# 602
# Translated Litígio to litigation for column Jurisdiction, row 602
#
#
# 603
# Translated Litígio to litigation for column Jurisdiction, row 603
#
#
# 604
# Translated Litígio to litigation for column Jurisdiction, row 604
#
#
# 605
# Translated Litígio to litigation for column Jurisdiction, row 605
#
#
# 606
# Translated Litígio to litigation for column Jurisdiction, row 606
#
#
# 607
# Translated Litígio to litigation for column Jurisdiction, row 607
#
#
# 608
# Translated Litígio to litigation for column Jurisdiction, row 608
#
#
# 609
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 609
#
#
# 610
# Translated Delimitada to bounded for column Jurisdiction, row 610
#
#
# 611
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 611
#
#
# 612
# Translated Litígio to litigation for column Jurisdiction, row 612
#
#
# 613
# Translated Litígio to litigation for column Jurisdiction, row 613
#
#
# 614
# Translated Litígio to litigation for column Jurisdiction, row 614
#
#
# 615
# Translated Litígio to litigation for column Jurisdiction, row 615
#
#
# 616
# Translated Litígio to litigation for column Jurisdiction, row 616
#
#
# 617
# Translated Litígio to litigation for column Jurisdiction, row 617
#
#
# 618
# Translated Litígio to litigation for column Jurisdiction, row 618
#
#
# 619
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 619
#
#
# 620
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 620
#
#
# 621
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 621
#
#
# 622
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 622
#
#
# 623
# Translated Litígio to litigation for column Jurisdiction, row 623
#
#
# 624
# Translated Litígio to litigation for column Jurisdiction, row 624
#
#
# 625
# Translated Litígio to litigation for column Jurisdiction, row 625
#
#
# 626
# Translated Homologada to homologated for column Jurisdiction, row 626
#
#
# 627
# Translated Homologada to homologated for column Jurisdiction, row 627
#
#
# 628
# Translated Área Titulada to Entitled area for column Jurisdiction, row 628
#
#
# 629
# Translated Litígio to litigation for column Jurisdiction, row 629
#
#
# 630
# Translated Litígio to litigation for column Jurisdiction, row 630
#
#
# 631
# Translated Litígio to litigation for column Jurisdiction, row 631
#
#
# 632
# ...
#
#
# 696
# Translated Litígio to litigation for column Jurisdiction, row 696
#
#
# 697
# Translated Litígio to litigation for column Jurisdiction, row 697
#
#
# 698
# Translated Litígio to litigation for column Jurisdiction, row 698
#
#
# 699
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 699
#
#
# 700
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 700
#
#
# 701
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 701
#
#
# 702
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 702
#
#
# 703
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 703
#
#
# 704
# Translated Litígio to litigation for column Jurisdiction, row 704
#
#
# 705
# Translated Homologada to homologated for column Jurisdiction, row 705
#
#
# 706
# Translated Homologada to homologated for column Jurisdiction, row 706
#
#
# 707
# Translated Homologada to homologated for column Jurisdiction, row 707
#
#
# 708
# Translated Homologada to homologated for column Jurisdiction, row 708
#
#
# 709
# Translated Homologada to homologated for column Jurisdiction, row 709
#
#
# 710
# Translated Litígio to litigation for column Jurisdiction, row 710
#
#
# 711
# Translated Litígio to litigation for column Jurisdiction, row 711
#
#
# 712
# Translated Litígio to litigation for column Jurisdiction, row 712
#
#
# 713
# Translated Litígio to litigation for column Jurisdiction, row 713
#
#
# 714
# Translated Litígio to litigation for column Jurisdiction, row 714
#
#
# 715
# Translated Litígio to litigation for column Jurisdiction, row 715
#
#
# 716
# Translated Litígio to litigation for column Jurisdiction, row 716
#
#
# 717
# Translated Litígio to litigation for column Jurisdiction, row 717
#
#
# 718
# Translated Litígio to litigation for column Jurisdiction, row 718
#
#
# 719
# Translated Litígio to litigation for column Jurisdiction, row 719
#
#
# 720
# Translated Litígio to litigation for column Jurisdiction, row 720
#
#
# 721
# Translated Litígio to litigation for column Jurisdiction, row 721
#
#
# 722
# Translated Litígio to litigation for column Jurisdiction, row 722
#
#
# 723
# Translated Litígio to litigation for column Jurisdiction, row 723
#
#
# 724
# Translated Litígio to litigation for column Jurisdiction, row 724
#
#
# 725
# Translated Litígio to litigation for column Jurisdiction, row 725
#
#
# 726
# Translated Litígio to litigation for column Jurisdiction, row 726
#
#
# 727
# Translated Litígio to litigation for column Jurisdiction, row 727
#
#
# 728
# Translated Litígio to litigation for column Jurisdiction, row 728
#
#
# 729
# Translated Litígio to litigation for column Jurisdiction, row 729
#
#
# 730
# Translated Litígio to litigation for column Jurisdiction, row 730
#
#
# 731
# Translated Litígio to litigation for column Jurisdiction, row 731
#
#
# 732
# Translated Litígio to litigation for column Jurisdiction, row 732
#
#
# 733
# Translated Litígio to litigation for column Jurisdiction, row 733
#
#
# 734
# Translated Litígio to litigation for column Jurisdiction, row 734
#
#
# 735
# Translated Litígio to litigation for column Jurisdiction, row 735
#
#
# 736
# Translated Litígio to litigation for column Jurisdiction, row 736
#
#
# 737
# Translated Litígio to litigation for column Jurisdiction, row 737
#
#
# 738
# Translated Não desapropriá vel to Not evict level for column Jurisdiction, row 738
#
#
# 739
# Translated Litígio to litigation for column Jurisdiction, row 739
#
#
# 740
# Translated Litígio to litigation for column Jurisdiction, row 740
#
#
# 741
# Translated Reconhecid a to Reconhecid the for column Jurisdiction, row 741
#
#
# 742
# Translated Litígio to litigation for column Jurisdiction, row 742
#
#
# 743
# Translated Certificada to certified for column Jurisdiction, row 743
#
#
# 744
# Translated Certificada to certified for column Jurisdiction, row 744
#
#
# 745
# Translated Litígio to litigation for column Jurisdiction, row 745
#
#
# 746
# Translated Litígio to litigation for column Jurisdiction, row 746
#
#
# 747
# Translated Litígio to litigation for column Jurisdiction, row 747
#
#
# 748
# Translated Litígio to litigation for column Jurisdiction, row 748
#
#
# 749
# Translated Homologada to homologated for column Jurisdiction, row 749
#
#
# 750
# Translated Sem informação to No information for column Jurisdiction, row 750
#
#
# 751
# Translated Litígio to litigation for column Jurisdiction, row 751
#
#
# 752
# Translated Litígio to litigation for column Jurisdiction, row 752
#
#
# 753
# Translated Litígio to litigation for column Jurisdiction, row 753
#
#
# 754
# Translated Litígio to litigation for column Jurisdiction, row 754
#
#
# 755
# Translated Litígio to litigation for column Jurisdiction, row 755
#
#
# 756
# Translated Litígio to litigation for column Jurisdiction, row 756
#
#
# 757
# Translated Litígio to litigation for column Jurisdiction, row 757
#
#
# 758
# Translated Litígio to litigation for column Jurisdiction, row 758
#
#
# 759
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 759
#
#
# 760
# Translated Homologada to homologated for column Jurisdiction, row 760
#
#
# 761
# Translated Homologada to homologated for column Jurisdiction, row 761
#
#
# 762
# Translated Litígio to litigation for column Jurisdiction, row 762
#
#
# 763
# Translated Litígio to litigation for column Jurisdiction, row 763
#
#
# 764
# Translated Litígio to litigation for column Jurisdiction, row 764
#
#
# 765
# Translated Litígio to litigation for column Jurisdiction, row 765
#
#
# 766
# Translated Litígio to litigation for column Jurisdiction, row 766
#
#
# 767
# Translated Litígio to litigation for column Jurisdiction, row 767
#
#
# 768
# Translated Litígio to litigation for column Jurisdiction, row 768
#
#
# 769
# Translated Homologada to homologated for column Jurisdiction, row 769
#
#
# 770
# Translated Homologada to homologated for column Jurisdiction, row 770
#
#
# 771
# Translated Litígio to litigation for column Jurisdiction, row 771
#
#
# 772
# Translated Litígio to litigation for column Jurisdiction, row 772
#
#
# 773
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 773
#
#
# 774
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 774
#
#
# 775
# Translated Reconhecid a to Reconhecid the for column Jurisdiction, row 775
#
#
# 776
# Translated Litígio to litigation for column Jurisdiction, row 776
#
#
# 777
# Translated Homologada to homologated for column Jurisdiction, row 777
#
#
# 778
# Translated Homologada to homologated for column Jurisdiction, row 778
#
#
# 779
# Translated Homologada to homologated for column Jurisdiction, row 779
#
#
# 780
# Translated Homologada to homologated for column Jurisdiction, row 780
#
#
# 781
# Translated Homologada to homologated for column Jurisdiction, row 781
#
#
# 782
# Translated Homologada to homologated for column Jurisdiction, row 782
#
#
# 783
# Translated Reconhecid a to Reconhecid the for column Jurisdiction, row 783
#
#
# 784
# Translated Reconhecid a to Reconhecid the for column Jurisdiction, row 784
#
#
# 785
# Translated Litígio to litigation for column Jurisdiction, row 785
#
#
# 786
# Translated Litígio to litigation for column Jurisdiction, row 786
#
#
# 787
# Translated Litígio to litigation for column Jurisdiction, row 787
#
#
# 788
# Translated Litígio to litigation for column Jurisdiction, row 788
#
#
# 789
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 789
#
#
# 790
# Translated Litígio to litigation for column Jurisdiction, row 790
#
#
# 791
# Translated Litígio to litigation for column Jurisdiction, row 791
#
#
# 792
# Translated Homologada to homologated for column Jurisdiction, row 792
#
#
# 793
# Translated Litígio to litigation for column Jurisdiction, row 793
#
#
# 794
# Translated Litígio to litigation for column Jurisdiction, row 794
#
#
# 795
# Translated Demarcada to demarcated for column Jurisdiction, row 795
#
#
# 796
# Translated Homologada to homologated for column Jurisdiction, row 796
#
#
# 797
# Translated Litígio to litigation for column Jurisdiction, row 797
#
#
# 798
# Translated Litígio to litigation for column Jurisdiction, row 798
#
#
# 799
# Translated Litígio to litigation for column Jurisdiction, row 799
#
#
# 800
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 800
#
#
# 801
# Translated Demarcada to demarcated for column Jurisdiction, row 801
#
#
# 802
# Translated Litígio to litigation for column Jurisdiction, row 802
#
#
# 803
# Translated Litígio to litigation for column Jurisdiction, row 803
#
#
# 804
# Translated Litígio to litigation for column Jurisdiction, row 804
#
#
# 805
# Translated Grilada to illegally taken for column Jurisdiction, row 805
#
#
# 806
# Translated Litígio to litigation for column Jurisdiction, row 806
#
#
# 807
# Translated Litígio to litigation for column Jurisdiction, row 807
#
#
# 808
# Translated Litígio to litigation for column Jurisdiction, row 808
#
#
# 809
# Translated Litígio to litigation for column Jurisdiction, row 809
#
#
# 810
# Translated Litígio to litigation for column Jurisdiction, row 810
#
#
# 811
# Translated Litígio to litigation for column Jurisdiction, row 811
#
#
# 812
# Translated Homologada to homologated for column Jurisdiction, row 812
#
#
# 813
# Translated Homologada to homologated for column Jurisdiction, row 813
#
#
# 814
# Translated Litígio to litigation for column Jurisdiction, row 814
#
#
# 815
# Translated Homologada to homologated for column Jurisdiction, row 815
#
#
# 816
# Translated Homologada to homologated for column Jurisdiction, row 816
#
#
# 817
# Translated Sem informação to No information for column Jurisdiction, row 817
#
#
# 818
# Translated Homologada to homologated for column Jurisdiction, row 818
#
#
# 819
# Translated Homologada to homologated for column Jurisdiction, row 819
#
#
# 820
# Translated Homologada to homologated for column Jurisdiction, row 820
#
#
# 821
# Translated Homologada to homologated for column Jurisdiction, row 821
#
#
# 822
# Translated Homologada to homologated for column Jurisdiction, row 822
#
#
# 823
# Translated Homologada to homologated for column Jurisdiction, row 823
#
#
# 824
# Translated Homologada to homologated for column Jurisdiction, row 824
#
#
# 825
# Translated Homologada to homologated for column Jurisdiction, row 825
#
#
# 826
# Translated Homologada to homologated for column Jurisdiction, row 826
#
#
# 827
# Translated Homologada to homologated for column Jurisdiction, row 827
#
#
# 828
# Translated Litígio to litigation for column Jurisdiction, row 828
#
#
# 829
# Translated Titulada to entitled for column Jurisdiction, row 829
#
#
# 830
# Translated Sem informação to No information for column Jurisdiction, row 830
#
#
# 831
# Translated Sem informação to No information for column Jurisdiction, row 831
#
#
# 832
# Translated Certificada to certified for column Jurisdiction, row 832
#
#
# 833
# Translated Demarcada to demarcated for column Jurisdiction, row 833
#
#
# 834
# Translated Certificada to certified for column Jurisdiction, row 834
#
#
# 835
# Translated Certificada to certified for column Jurisdiction, row 835
#
#
# 836
# Translated Certificada to certified for column Jurisdiction, row 836
#
#
# 837
# Translated Certificada to certified for column Jurisdiction, row 837
#
#
# 838
# Translated Certificada to certified for column Jurisdiction, row 838
#
#
# 839
# Translated Certificada to certified for column Jurisdiction, row 839
#
#
# 840
# Translated Certificada to certified for column Jurisdiction, row 840
#
#
# 841
# Translated Certificada to certified for column Jurisdiction, row 841
#
#
# 842
# Translated Certificada to certified for column Jurisdiction, row 842
#
#
# 843
# Translated Certificada to certified for column Jurisdiction, row 843
#
#
# 844
# Translated Sem informação to No information for column Jurisdiction, row 844
#
#
# 845
# Translated Sem informação to No information for column Jurisdiction, row 845
#
#
# 846
# Translated Litígio to litigation for column Jurisdiction, row 846
#
#
# 847
# Translated Litígio to litigation for column Jurisdiction, row 847
#
#
# 848
# Translated Litígio to litigation for column Jurisdiction, row 848
#
#
# 849
# Translated Litígio to litigation for column Jurisdiction, row 849
#
#
# 850
# Translated Litígio to litigation for column Jurisdiction, row 850
#
#
# 851
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 851
#
#
# 852
# Translated Litígio to litigation for column Jurisdiction, row 852
#
#
# 853
# Translated Litígio to litigation for column Jurisdiction, row 853
#
#
# 854
# Translated Litígio to litigation for column Jurisdiction, row 854
#
#
# 855
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 855
#
#
# 856
# Translated Litígio to litigation for column Jurisdiction, row 856
#
#
# 857
# Translated Litígio to litigation for column Jurisdiction, row 857
#
#
# 858
# Translated Litígio to litigation for column Jurisdiction, row 858
#
#
# 859
# Translated Litígio to litigation for column Jurisdiction, row 859
#
#
# 860
# Translated Litígio to litigation for column Jurisdiction, row 860
#
#
# 861
# Translated Litígio to litigation for column Jurisdiction, row 861
#
#
# 862
# Translated Litígio to litigation for column Jurisdiction, row 862
#
#
# 863
# Translated Litígio to litigation for column Jurisdiction, row 863
#
#
# 864
# Translated Litígio to litigation for column Jurisdiction, row 864
#
#
# 865
# Translated Litígio to litigation for column Jurisdiction, row 865
#
#
# 866
# Translated Litígio to litigation for column Jurisdiction, row 866
#
#
# 867
# Translated Litígio to litigation for column Jurisdiction, row 867
#
#
# 868
# Translated Litígio to litigation for column Jurisdiction, row 868
#
#
# 869
# Translated Litígio to litigation for column Jurisdiction, row 869
#
#
# 870
# Translated Litígio to litigation for column Jurisdiction, row 870
#
#
# 871
# Translated Litígio to litigation for column Jurisdiction, row 871
#
#
# 872
# Translated Litígio to litigation for column Jurisdiction, row 872
#
#
# 873
# Translated Litígio to litigation for column Jurisdiction, row 873
#
#
# 874
# Translated Litígio to litigation for column Jurisdiction, row 874
#
#
# 875
# Translated Litígio to litigation for column Jurisdiction, row 875
#
#
# 876
# Translated Litígio to litigation for column Jurisdiction, row 876
#
#
# 877
# Translated Litígio to litigation for column Jurisdiction, row 877
#
#
# 878
# Translated Litígio to litigation for column Jurisdiction, row 878
#
#
# 879
# Translated Litígio to litigation for column Jurisdiction, row 879
#
#
# 880
# Translated Delimitada to bounded for column Jurisdiction, row 880
#
#
# 881
# Translated Certificada to certified for column Jurisdiction, row 881
#
#
# 882
# Translated Litígio to litigation for column Jurisdiction, row 882
#
#
# 883
# Translated Litígio to litigation for column Jurisdiction, row 883
#
#
# 884
# Translated Litígio to litigation for column Jurisdiction, row 884
#
#
# 885
# Translated Litígio to litigation for column Jurisdiction, row 885
#
#
# 886
# Translated Litígio to litigation for column Jurisdiction, row 886
#
#
# 887
# Translated Litígio to litigation for column Jurisdiction, row 887
#
#
# 888
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 888
#
#
# 889
# Translated Litígio to litigation for column Jurisdiction, row 889
#
#
# 890
# Translated Delimitada to bounded for column Jurisdiction, row 890
#
#
# 891
# Translated Litígio to litigation for column Jurisdiction, row 891
#
#
# 892
# Translated Litígio to litigation for column Jurisdiction, row 892
#
#
# 893
# Translated Certificada to certified for column Jurisdiction, row 893
#
#
# 894
# Translated Certificada to certified for column Jurisdiction, row 894
#
#
# 895
# Translated Certificada to certified for column Jurisdiction, row 895
#
#
# 896
# Translated Certificada to certified for column Jurisdiction, row 896
#
#
# 897
# Translated Litígio to litigation for column Jurisdiction, row 897
#
#
# 898
# Translated Litígio to litigation for column Jurisdiction, row 898
#
#
# 899
# Translated Litígio to litigation for column Jurisdiction, row 899
#
#
# 900
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 900
#
#
# 901
# Translated Litígio to litigation for column Jurisdiction, row 901
#
#
# 902
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 902
#
#
# 903
# Translated Assentamen to to Assentamen to for column Jurisdiction, row 903
#
#
# 904
# Translated Litígio to litigation for column Jurisdiction, row 904
#
#
# 905
# Translated Certificada to certified for column Jurisdiction, row 905
#
#
# 906
# Translated Em fase de Reconhecim ento to In recognition phase for column Jurisdiction, row 906
#
#
# 907
# Translated Homologada to homologated for column Jurisdiction, row 907

# %%
data.to_csv(data_location_en, index = False)
